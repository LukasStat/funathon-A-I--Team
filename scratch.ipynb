# %%
# If you need to change working directory (default is your interactive .py file location)
# import os
# os.chdir("<NEW_RELATIVE_LOCATION>")

import pandas as pd

df = pd.read_parquet(
    "https://minio.lab.sspcloud.fr/projet-formation/diffusion/funathon/2026/project2/generation_None_temp08.parquet"
)
df.head()
# Out:
#     code                                               name  \
# 0  01.11  Growing of cereals, other than rice, leguminou...
# 1  01.11  Growing of cereals, other than rice, leguminou...
# 2  01.11  Growing of cereals, other than rice, leguminou...
# 3  01.11  Growing of cereals, other than rice, leguminou...
# 4  01.11  Growing of cereals, other than rice, leguminou...
#
#                                 label
# 0       Pulses cultivation for market
# 1   Legume crop production activities
# 2       Broad bean farming operations
# 3  Chickpea harvesting and processing
# 4  Production of dried beans and peas
